# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
x = [5,2,3,4,5]


plt.plot(x)

# %%
# plot y = x^2
x = range(-4, 5)
y = [x**2 for x in x]

plt.plot(x,y)

# %% [markdown]
# ## Interactive Documentation in Jupyter Notebooks
#
# put your cursor within parenthese of a function call and press "shift + tab" to see the documentation for that function
